# %%
# !pip install openpyxl
import pandas as pd

# %%
dataset = pd.read_excel("flood dataset.xlsx")

# %%
print("First Five Records:")
display(dataset.head())
# Out:
# First Five Records:
#    Temp  Humidity  Cloud Cover  ANNUAL  Jan-Feb  Mar-May  Jun-Sep  Oct-Dec  \
# 0    29        70           30  3248.6     73.4    386.2   2122.8    666.1
# 1    28        75           40  3326.6      9.3    275.7   2403.4    638.2
# 2    28        75           42  3271.2     21.7    336.3   2343.0    570.1
# 3    29        71           44  3129.7     26.7    339.4   2398.2    365.3
# 4    31        74           40  2741.6     23.4    378.5   1881.5    458.1
#
#       avgjune    sub  flood
# 0  274.866667  649.9      0
# 1  130.300000  256.4      1
# 2  186.200000  308.9      0
# 3  366.066667  862.5      0
# 4  283.400000  586.9      0

# %%
print("\nDataset Shape:", dataset.shape)
# Out:
# Dataset Shape: (115, 11)

# %%
print("\nColumn Names:")
print(dataset.columns.tolist())
# Out:
# Column Names:
# ['Temp', 'Humidity', 'Cloud Cover', 'ANNUAL', 'Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec', 'avgjune', 'sub', 'flood']

# %%
print("\nDataset Information:")
dataset.info()
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temp         115 non-null    int64
#  1   Humidity     115 non-null    int64
#  2   Cloud Cover  115 non-null    int64
#  3   ANNUAL       115 non-null    float64
#  4   Jan-Feb      115 non-null    float64
#  5   Mar-May      115 non-null    float64
#  6   Jun-Sep      115 non-null    float64
#  7   Oct-Dec      115 non-null    float64
#  8   avgjune      115 non-null    float64
#  9   sub          115 non-null    float64
#  10  flood        115 non-null    int64
# dtypes: float64(7), int64(4)
# memory usage: 10.0 KB

# %%
print("\nMissing Values:")
print(dataset.isnull().sum())
# Out:
# Missing Values:
# Temp           0
# Humidity       0
# Cloud Cover    0
# ANNUAL         0
# Jan-Feb        0
# Mar-May        0
# Jun-Sep        0
# Oct-Dec        0
# avgjune        0
# sub            0
# flood          0
# dtype: int64

# %%
print("\nStatistical Summary:")
display(dataset.describe())
# Out:
# Statistical Summary:
#              Temp    Humidity  Cloud Cover       ANNUAL     Jan-Feb  \
# count  115.000000  115.000000   115.000000   115.000000  115.000000
# mean    29.600000   73.852174    36.286957  2925.487826   27.739130
# std      1.122341    2.947623     4.330158   422.112193   22.361032
# min     28.000000   70.000000    30.000000  2068.800000    0.300000
# 25%     29.000000   71.000000    32.500000  2627.900000   10.250000
# 50%     30.000000   74.000000    36.000000  2937.500000   20.500000
# 75%     31.000000   76.000000    40.000000  3164.100000   41.600000
# max     31.000000   79.000000    44.000000  4257.800000   98.100000
#
#           Mar-May      Jun-Sep     Oct-Dec     avgjune         sub       flood
# count  115.000000   115.000000  115.000000  115.000000  115.000000  115.000000
# mean   377.253913  2022.840870  497.636522  218.100870  439.801739    0.139130
# std    151.091850   386.254397  129.860643   62.547597  210.438813    0.347597
# ...

# %%
# !pip install xgboost

# %%
dataset.head()
# Out:
#    Temp  Humidity  Cloud Cover  ANNUAL  Jan-Feb  Mar-May  Jun-Sep  Oct-Dec  \
# 0    29        70           30  3248.6     73.4    386.2   2122.8    666.1
# 1    28        75           40  3326.6      9.3    275.7   2403.4    638.2
# 2    28        75           42  3271.2     21.7    336.3   2343.0    570.1
# 3    29        71           44  3129.7     26.7    339.4   2398.2    365.3
# 4    31        74           40  2741.6     23.4    378.5   1881.5    458.1
#
#       avgjune    sub  flood
# 0  274.866667  649.9      0
# 1  130.300000  256.4      1
# 2  186.200000  308.9      0
# 3  366.066667  862.5      0
# 4  283.400000  586.9      0

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
from xgboost import XGBClassifier

# %%
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    classification_report
)

# %%
import joblib
import pickle

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
print("All libraries imported successfully!")
# Out:
# All libraries imported successfully!

# %%
plt.style.use("ggplot")

# %%
dataset.head()
# Out:
#    Temp  Humidity  Cloud Cover  ANNUAL  Jan-Feb  Mar-May  Jun-Sep  Oct-Dec  \
# 0    29        70           30  3248.6     73.4    386.2   2122.8    666.1
# 1    28        75           40  3326.6      9.3    275.7   2403.4    638.2
# 2    28        75           42  3271.2     21.7    336.3   2343.0    570.1
# 3    29        71           44  3129.7     26.7    339.4   2398.2    365.3
# 4    31        74           40  2741.6     23.4    378.5   1881.5    458.1
#
#       avgjune    sub  flood
# 0  274.866667  649.9      0
# 1  130.300000  256.4      1
# 2  186.200000  308.9      0
# 3  366.066667  862.5      0
# 4  283.400000  586.9      0

# %%
dataset.shape
# Out:
# (115, 11)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temp         115 non-null    int64
#  1   Humidity     115 non-null    int64
#  2   Cloud Cover  115 non-null    int64
#  3   ANNUAL       115 non-null    float64
#  4   Jan-Feb      115 non-null    float64
#  5   Mar-May      115 non-null    float64
#  6   Jun-Sep      115 non-null    float64
#  7   Oct-Dec      115 non-null    float64
#  8   avgjune      115 non-null    float64
#  9   sub          115 non-null    float64
#  10  flood        115 non-null    int64
# dtypes: float64(7), int64(4)
# memory usage: 10.0 KB

# %%
dataset.describe()
# Out:
#              Temp    Humidity  Cloud Cover       ANNUAL     Jan-Feb  \
# count  115.000000  115.000000   115.000000   115.000000  115.000000
# mean    29.600000   73.852174    36.286957  2925.487826   27.739130
# std      1.122341    2.947623     4.330158   422.112193   22.361032
# min     28.000000   70.000000    30.000000  2068.800000    0.300000
# 25%     29.000000   71.000000    32.500000  2627.900000   10.250000
# 50%     30.000000   74.000000    36.000000  2937.500000   20.500000
# 75%     31.000000   76.000000    40.000000  3164.100000   41.600000
# max     31.000000   79.000000    44.000000  4257.800000   98.100000
#
#           Mar-May      Jun-Sep     Oct-Dec     avgjune         sub       flood
# count  115.000000   115.000000  115.000000  115.000000  115.000000  115.000000
# mean   377.253913  2022.840870  497.636522  218.100870  439.801739    0.139130
# std    151.091850   386.254397  129.860643   62.547597  210.438813    0.347597
# ...

# %%
dataset.isnull().sum()
# Out:
# Temp           0
# Humidity       0
# Cloud Cover    0
# ANNUAL         0
# Jan-Feb        0
# Mar-May        0
# Jun-Sep        0
# Oct-Dec        0
# avgjune        0
# sub            0
# flood          0
# dtype: int64

# %%
dataset.dtypes
# Out:
# Temp             int64
# Humidity         int64
# Cloud Cover      int64
# ANNUAL         float64
# Jan-Feb        float64
# Mar-May        float64
# Jun-Sep        float64
# Oct-Dec        float64
# avgjune        float64
# sub            float64
# flood            int64
# dtype: object

# %%
for i in dataset.select_dtypes(include='number').columns:
    plt.figure(figsize=(6,4))
    sns.histplot(dataset[i], kde=True)
    plt.title(i)
    plt.show()

# %%
for i in dataset.select_dtypes(include='number').columns:
    plt.figure(figsize=(6,4))
    sns.boxplot(x=dataset[i])
    plt.title(i)
    plt.show()

# %%
sns.countplot(x='flood', data=dataset)
plt.show()

# %%
dataset.corr(numeric_only=True)
# Out:
#                  Temp  Humidity  Cloud Cover    ANNUAL   Jan-Feb   Mar-May  \
# Temp         1.000000 -0.012727    -0.046568 -0.063014 -0.080076  0.099519
# Humidity    -0.012727  1.000000     0.085824 -0.054767 -0.185965 -0.101232
# Cloud Cover -0.046568  0.085824     1.000000  0.051166  0.004376  0.096645
# ANNUAL      -0.063014 -0.054767     0.051166  1.000000  0.033639  0.387790
# Jan-Feb     -0.080076 -0.185965     0.004376  0.033639  1.000000  0.066479
# Mar-May      0.099519 -0.101232     0.096645  0.387790  0.066479  1.000000
# Jun-Sep     -0.081965 -0.029583     0.010833  0.861190  0.001178 -0.029007
# Oct-Dec     -0.063034  0.059739     0.020966  0.232069 -0.143670  0.171805
# avgjune     -0.019751  0.017656    -0.089843  0.474644  0.164691  0.019183
# sub         -0.088331  0.029981    -0.106455  0.220009  0.201266 -0.475750
# flood       -0.080946  0.020250     0.089801  0.626874 -0.084446 -0.017598
#
#               Jun-Sep   Oct-Dec   avgjune       sub     flood
# ...

# %%
plt.figure(figsize=(12,8))
sns.heatmap(dataset.corr(numeric_only=True), annot=True, cmap='summer')
plt.show()

# %%
sns.pairplot(dataset, hue='flood')
plt.show()

# %%
sns.pairplot(dataset[['Temp','Humidity','Cloud Cover','ANNUAL','flood']], hue='flood')
plt.show()

# %%
sns.scatterplot(x='Temp', y='Humidity', hue='flood', data=dataset)
plt.show()

# %%
sns.scatterplot(x='ANNUAL', y='flood', data=dataset)
plt.show()

# %%
sns.boxplot(x='flood', y='Cloud Cover', data=dataset)
plt.show()

# %%
sns.boxplot(x='flood', y='Humidity', data=dataset)
plt.show()

# %%
sns.boxplot(x='flood', y='Temp', data=dataset)
plt.show()

# %%
sns.boxplot(x='flood', y='ANNUAL', data=dataset)
plt.show()

# %%
dataset['flood'].value_counts()
# Out:
# flood
# 0    99
# 1    16
# Name: count, dtype: int64

# %%
dataset.nunique()
# Out:
# Temp             4
# Humidity        10
# Cloud Cover     15
# ANNUAL         115
# Jan-Feb        103
# Mar-May        111
# Jun-Sep        113
# Oct-Dec        115
# avgjune        113
# sub            114
# flood            2
# dtype: int64

# %%
dataset.duplicated().sum()
# Out:
# np.int64(0)

# %%
dataset.sample(10)
# Out:
#     Temp  Humidity  Cloud Cover  ANNUAL  Jan-Feb  Mar-May  Jun-Sep  Oct-Dec  \
# 9     30        70           34  2848.6     28.4    296.7   1886.5    637.0
# 1     28        75           40  3326.6      9.3    275.7   2403.4    638.2
# 38    29        74           39  2937.5     17.2    302.8   1969.4    648.1
# 49    31        77           39  3146.6     53.8    341.5   2342.9    408.4
# 20    31        79           43  2719.9     47.8    290.3   1927.5    454.3
# 29    30        70           38  3018.0     21.6    546.5   1719.7    730.2
# 25    30        70           38  2965.4     34.4    301.5   2307.8    321.7
# 72    29        75           44  2412.5      0.3    263.8   1749.2    399.2
# 98    28        79           39  2914.6     25.5    586.2   1661.9    640.9
# 36    29        72           33  2818.2     27.7    371.3   1877.1    542.0
#
#        avgjune    sub  flood
# 9   226.666667  531.2      0
# 1   130.300000  256.4      1
# 38  208.600000  520.7      0
# ...

# %%
dataset.isnull().sum()
# Out:
# Temp           0
# Humidity       0
# Cloud Cover    0
# ANNUAL         0
# Jan-Feb        0
# Mar-May        0
# Jun-Sep        0
# Oct-Dec        0
# avgjune        0
# sub            0
# flood          0
# dtype: int64

# %%
dataset.isnull().any()
# Out:
# Temp           False
# Humidity       False
# Cloud Cover    False
# ANNUAL         False
# Jan-Feb        False
# Mar-May        False
# Jun-Sep        False
# Oct-Dec        False
# avgjune        False
# sub            False
# flood          False
# dtype: bool

# %%
num_cols = dataset.select_dtypes(include=np.number).columns.drop('flood')

for col in num_cols:
    Q1 = dataset[col].quantile(0.25)
    Q3 = dataset[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    dataset[col] = np.where(dataset[col] < lower, lower, dataset[col])
    dataset[col] = np.where(dataset[col] > upper, upper, dataset[col])

# %%
for col in num_cols:
    plt.figure(figsize=(6,3))
    sns.boxplot(x=dataset[col])
    plt.title(col)
    plt.show()

# %%
dataset['flood'].unique()
# Out:
# array([0, 1])

# %%
X = dataset.drop('flood', axis=1)

y = dataset['flood']

# %%
X.head()
# Out:
#    Temp  Humidity  Cloud Cover  ANNUAL  Jan-Feb  Mar-May  Jun-Sep  Oct-Dec  \
# 0  29.0      70.0         30.0  3248.6     73.4    386.2   2122.8    666.1
# 1  28.0      75.0         40.0  3326.6      9.3    275.7   2403.4    638.2
# 2  28.0      75.0         42.0  3271.2     21.7    336.3   2343.0    570.1
# 3  29.0      71.0         44.0  3129.7     26.7    339.4   2398.2    365.3
# 4  31.0      74.0         40.0  2741.6     23.4    378.5   1881.5    458.1
#
#       avgjune    sub
# 0  274.866667  649.9
# 1  130.300000  256.4
# 2  186.200000  308.9
# 3  366.066667  862.5
# 4  283.400000  586.9

# %%
y.head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    0
# 4    0
# Name: flood, dtype: int64

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.25,
    random_state=10
)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (86, 10)
# (29, 10)
# (86,)
# (29,)

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()

x_train = sc.fit_transform(x_train)

x_test = sc.transform(x_test)

# %%
import joblib

joblib.dump(sc, 'scaler.pkl')
# Out:
# ['scaler.pkl']

# %%
import os

os.listdir()
# Out:
# ['.config',
#  'flood dataset.xlsx',
#  'scaler.pkl',
#  '.ipynb_checkpoints',
#  'sample_data']

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

import pandas as pd

# %%
dtree = DecisionTreeClassifier(random_state=42)

dtree.fit(x_train, y_train)

p1 = dtree.predict(x_test)

print("Decision Tree Accuracy :", accuracy_score(y_test,p1))
print(confusion_matrix(y_test,p1))
print(classification_report(y_test,p1))
# Out:
# Decision Tree Accuracy : 0.9655172413793104
# [[26  0]
#  [ 1  2]]
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        26
#            1       1.00      0.67      0.80         3
#
#     accuracy                           0.97        29
#    macro avg       0.98      0.83      0.89        29
# weighted avg       0.97      0.97      0.96        29

# %%
rf = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

rf.fit(x_train,y_train)

p2 = rf.predict(x_test)

print("Random Forest Accuracy :", accuracy_score(y_test,p2))
print(confusion_matrix(y_test,p2))
print(classification_report(y_test,p2))
# Out:
# Random Forest Accuracy : 0.9655172413793104
# [[26  0]
#  [ 1  2]]
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        26
#            1       1.00      0.67      0.80         3
#
#     accuracy                           0.97        29
#    macro avg       0.98      0.83      0.89        29
# weighted avg       0.97      0.97      0.96        29

# %%
knn = KNeighborsClassifier(n_neighbors=5)

knn.fit(x_train,y_train)

p3 = knn.predict(x_test)

print("KNN Accuracy :", accuracy_score(y_test,p3))
print(confusion_matrix(y_test,p3))
print(classification_report(y_test,p3))
# Out:
# KNN Accuracy : 0.9310344827586207
# [[25  1]
#  [ 1  2]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96        26
#            1       0.67      0.67      0.67         3
#
#     accuracy                           0.93        29
#    macro avg       0.81      0.81      0.81        29
# weighted avg       0.93      0.93      0.93        29

# %%
xgb = XGBClassifier(
    random_state=42,
    eval_metric="logloss"
)

xgb.fit(x_train,y_train)

p4 = xgb.predict(x_test)

print("XGBoost Accuracy :", accuracy_score(y_test,p4))
print(confusion_matrix(y_test,p4))
print(classification_report(y_test,p4))
# Out:
# XGBoost Accuracy : 0.9655172413793104
# [[26  0]
#  [ 1  2]]
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        26
#            1       1.00      0.67      0.80         3
#
#     accuracy                           0.97        29
#    macro avg       0.98      0.83      0.89        29
# weighted avg       0.97      0.97      0.96        29

# %%
models = pd.DataFrame({

    "Model":[
        "Decision Tree",
        "Random Forest",
        "KNN",
        "XGBoost"
    ],

    "Accuracy":[
        accuracy_score(y_test,p1),
        accuracy_score(y_test,p2),
        accuracy_score(y_test,p3),
        accuracy_score(y_test,p4)
    ]

})

models
# Out:
#            Model  Accuracy
# 0  Decision Tree  0.965517
# 1  Random Forest  0.965517
# 2            KNN  0.931034
# 3        XGBoost  0.965517

# %%
models.sort_values(
    by="Accuracy",
    ascending=False
)
# Out:
#            Model  Accuracy
# 0  Decision Tree  0.965517
# 1  Random Forest  0.965517
# 3        XGBoost  0.965517
# 2            KNN  0.931034

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

plt.bar(models["Model"],models["Accuracy"])

plt.ylabel("Accuracy")

plt.xlabel("Models")

plt.title("Model Comparison")

plt.show()

# %%
print("Decision Tree :",accuracy_score(y_test,p1))

print("Random Forest :",accuracy_score(y_test,p2))

print("KNN :",accuracy_score(y_test,p3))

print("XGBoost :",accuracy_score(y_test,p4))
# Out:
# Decision Tree : 0.9655172413793104
# Random Forest : 0.9655172413793104
# KNN : 0.9310344827586207
# XGBoost : 0.9655172413793104

# %%
best_model = xgb

# %%
import joblib

joblib.dump(best_model, "floods.save")
joblib.dump(sc, "transform.save")
# Out:
# ['transform.save']

# %%
import os

os.listdir()
# Out:
# ['.config',
#  'flood dataset.xlsx',
#  'floods.save',
#  'scaler.pkl',
#  '.ipynb_checkpoints',
#  'transform.save',
#  'sample_data']

# %%
loaded_model = joblib.load("floods.save")
loaded_scaler = joblib.load("transform.save")

# %%
sample = x_test[0].reshape(1, -1)

prediction = loaded_model.predict(sample)

print(prediction)
# Out:
# [0]

# %%
sample = x_test[0].reshape(1, -1)

prediction = loaded_model.predict(sample)

if prediction[0] == 1:
    print("Flood Chance")
else:
    print("No Flood Chance")
# Out:
# No Flood Chance
